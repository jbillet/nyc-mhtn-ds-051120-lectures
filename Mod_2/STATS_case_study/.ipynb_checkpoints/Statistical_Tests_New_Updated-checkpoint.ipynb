# %% [markdown]
# # Case Background & Key Questions
#
# Flatiron Health Insurance (FHI) is a growing private healthcare insurance provider founded on the premise that using data and analytics can improve the health insurance industry by providing better care and offerings to its patients. Every year, the Center for Disease Control (CDC) conducts surveys to understand the latest demographic, health, and fitness trends. You have been tasked with analyzing the recently published results of his years’ survey and providing your recommendations back to the Chief Analytics Officer and Chief Marketing Officer. You have been assigned the task of taking a first look at the data and beginning to answer several key questions:
#
# 1)  How does health status, represented by average number of days with bad physical health in the past month (PHYSHLTH), differ by state? Also provide an indication of distribution using whatever statistics you find suitable.
#
# 2)  Digging deeper into the data, what are some factors that impact health (i.e. demographics, behaviors, previous illness, etc.)?
#
# To get you started, the IT department formatted the data set into a tab delimited text file for only NY, NJ, and CT (FHI’s primary markets) called `case_studey.csv`. Below you will find a list of steps/questions that you will need to take in your investigation. The first part of the notebook will be focused on cleaning up your data and vidualizing it.  The second part of the data set will be focused on performing statistical tests to make statements with statistical significance.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# # pd.read_csv('case_study.csv')

# %%
#Load our dataframe account for the index columns
df = pd.read_csv('case_study.csv', index_col=0)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (171) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#        _STATE  FMONTH    IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 49938     9.0     5.0  5172017       5    17   2017    1200.0  2017000001
# 49939     9.0     2.0  2142017       2    14   2017    1200.0  2017000002
# 49940     9.0     1.0  1292017       1    29   2017    1200.0  2017000003
# 49941     9.0     7.0  9112017       9    11   2017    1200.0  2017000004
# 49942     9.0     5.0  7182017       7    18   2017    1200.0  2017000005
#
#                _PSU  CTELENM1  ...  _PA300R2  _PA30021  _PASTRNG  _PAREC1  \
# 49938  2.017000e+09       NaN  ...       2.0       2.0       2.0      4.0
# 49939  2.017000e+09       NaN  ...       1.0       1.0       1.0      1.0
# 49940  2.017000e+09       NaN  ...       3.0       2.0       1.0      3.0
# 49941  2.017000e+09       NaN  ...       2.0       2.0       2.0      2.0
# 49942  2.017000e+09       NaN  ...       2.0       2.0       1.0      1.0
#
#        _PASTAE1  _RFSEAT2  _RFSEAT3  _FLSHOT6  _PNEUMO2  _AIDTST3
# ...

# %%
# Quickly check to see the size of our DF, both rows and columns
df.shape
# Out:
# (34545, 358)

# %% [markdown]
# ## Subset your dataframe to only include the states in the tri-state area (NJ, CT, NY)

# %%
# your code here
tristatecode= [9, 34,36]
df= df[df._STATE.isin(tristatecode)]

# %% [markdown]
# Now check to see how large our subset df.

# %%
# your code here
df.shape
# Out:
# (34545, 358)

# %% [markdown]
# **PHYSHLTH** is the column we are interested in for this analysis, so let's start to investigate the column. Since we have a data cookbook, a.k.a. data dictionary) we want to start there before looking at the code.

# %%
df['PHYSHLTH'].describe()
# Out:
# count    34545.000000
# mean        60.213403
# std         37.504566
# min          1.000000
# 25%         15.000000
# 50%         88.000000
# 75%         88.000000
# max         99.000000
# Name: PHYSHLTH, dtype: float64

# %% [markdown]
# ## 1. Handle the non-normal values
#
# As you can see from the data dictionary, there are a number of responses that are coded with values that could throw off our descriptive statistics.  Let's clean up by mapping the responses to a more appropriate value, and handling any missing values.

# %%
#your code here
y= {99.0: float(df['PHYSHLTH'].median()), 77.0: float(df['PHYSHLTH'].median()), 88.0: 0.0}
df['PHYSHLTH'] = df['PHYSHLTH'].replace(y)
#df['PHYSHLTH'] = df['PHYSHLTH'].map(lambda x: float(df['PHYSHLTH'].mode()) if x == 99.0 or x== 77.0 else x)

# %%
df['PHYSHLTH'] = df['PHYSHLTH'].map(lambda x: 0 if x == 88.0 else x)

# %%
df['PHYSHLTH'].value_counts()
# Out:
# 0.0     22094
# 30.0     2438
# 2.0      1993
# 1.0      1538
# 3.0      1187
# 5.0      1092
# 10.0      751
# 7.0       641
# 15.0      640
# 4.0       622
# 20.0      402
# 14.0      326
# 6.0       187
# 25.0      159
# 8.0        99
# 21.0       70
# 12.0       69
# 28.0       57
# 29.0       35
# 27.0       22
# 18.0       19
# 16.0       16
# 17.0       15
# 9.0        15
# 22.0       12
# 13.0       10
# 19.0       10
# 11.0        8
# 24.0        7
# 26.0        7
# 23.0        4
# Name: PHYSHLTH, dtype: int64

# %%
df.shape
# Out:
# (34545, 358)

# %% [markdown]
# ## 2. Generate the descriptive statistics
#
# Now that our target variable is cleaned up lets calculate the descriptive statistics, generate a graph that quickly shows those statistics, and generate a graph shows the distribution of the data.

# %%
# descriptive statistics
df['PHYSHLTH'].describe()
# Out:
# count    34545.000000
# mean         3.990968
# std          8.436737
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          3.000000
# max         30.000000
# Name: PHYSHLTH, dtype: float64

# %%
fig, ax= plt.subplots()
ax.boxplot(df['PHYSHLTH'])
ax.set_ylabel('Days Sick')
ax.set_xticklabels('P');

# %%
# graphic the distribution of data
fig, ax= plt.subplots()
ax.hist(df['PHYSHLTH'], bins= 15)
ax.set_ylabel('Number of Days Sick')
ax.set_xlabel('# of Observations')
ax.set_title("Distribution of People's Sick Days");

# %% [markdown]
# ## 3. Generate a graphic that compares the average number of sick days for each state.

# %%
# code to calculate the average number of sick days by state
tristatemean= df.groupby('_STATE')['PHYSHLTH'].mean()

# %%
tristatemean.plot(kind= 'bar')

# %%
states_names= ['CONN', 'NJ', 'NY']

# %%
# code to graph those averages using matplotlib
fig, ax= plt.subplots()
ax.bar(states_names, tristatemean)
ax.set_ylabel('AVG Days Sick')
#ax.set_xlabel('State')
ax.set_title("Comparing Health by State");

# %%
# graphic showing the histogram of data
fig, ax= plt.subplots()
ax.hist(df[df['_STATE']==9.0]['PHYSHLTH'], density=True, histtype='step')
ax.hist(df[df['_STATE']==34.0]['PHYSHLTH'], density=True, histtype='step')
ax.hist(df[df['_STATE']==36.0]['PHYSHLTH'], density=True, histtype='step')
ax.legend(states_names)
ax.set_ylabel('# of Observations')
ax.set_xlabel('Sick Days')
ax.set_title("Distribution of People's Sick Days");

# %% [markdown]
# ## 4. Turn the number of sick days into a classification of of chronically sick people.
#
# Chronically sick people account for a significant proportion of the costs for health insurers. If we can identify what leads people to be chronically sick, we can address them with specific treatments.

# %%
# code to create new column for chronically sick
df['chronic']= np.where(df['PHYSHLTH']>10, 1,0)

# %% [markdown]
# ## 5. Create a graphic that compares the percentage of people labeled as 'sick' in each state.

# %%
# code to calculate averages per state
tristate_chronic= df.groupby('_STATE')['chronic'].mean()

# %%
# create graphic to compare chronically sick by state
fig, ax= plt.subplots()
ax.bar(states_names, tristate_chronic)
ax.set_ylabel('AVG Days Sick')
ax.set_title("Comparing Health by State");

# %% [markdown]
# ## 6. Independent Variables (categorical)
#
# Does smoking affect the number of days people feel physically ill?
# Let's take the column `SMOKDAY2` and start to prepare it so that we can see how it is possibly correlated to `PHYSHLTH`. When cleaning this data you will find that many respondents were not asked that question. read the codebook to understand why, and use that information when cleaning up your data. I.E, you will need to process two columns in order to create a new column of smokers.
#
# 1. Clean up the values.
# 2. Calculate the descriptive statistics of the variable.
# 3. Generate a histogram for the variable.
# 4. Generate graphics that show how the responses to this variable might differ by state.
# 5. Generate a graphic that compares the physical health of the different groups of 'smokers'.

# %%
df['SMOKDAY2'].value_counts()
# Out:
# 3.0    9703
# 1.0    2676
# 2.0    1371
# 9.0      27
# 7.0       6
# Name: SMOKDAY2, dtype: int64

# %%
df['SMOKDAY2'].value_counts().sum()
df['SMOKDAY2']
# Out:
# 49938     NaN
# 49939     NaN
# 49940     NaN
# 49941     NaN
# 49942     3.0
#          ...
# 303774    1.0
# 303775    NaN
# 303776    3.0
# 303777    NaN
# 303778    NaN
# Name: SMOKDAY2, Length: 34545, dtype: float64

# %%
df['smoking'] = np.where(df['SMOKE100']==2, 3, df['SMOKDAY2'])
df['smoking'] = np.where(df['SMOKE100']==7, 7, df['smoking'])
df['smoking'] = np.where(df['SMOKE100']==9, 9, df['smoking'])
# your code here
#conditions=[df['SMOKDAY2']==1,df['SMOKDAY2']==2,df['SMOKDAY2']==3,
#            df['SMOKDAY2']==7,df['SMOKDAY2']==9]
#choices=[1,2,3,7,9]
#df['Smokers']=np.select(conditions,choices,default=3)

# %%
df['smoking'].describe()
# Out:
# count    33095.000000
# mean         2.832754
# std          0.713282
# min          1.000000
# 25%          3.000000
# 50%          3.000000
# 75%          3.000000
# max          9.000000
# Name: smoking, dtype: float64

# %%
smoking_avg = df['smoking'].value_counts()/df['smoking'].count()
smoking_avg
# Out:
# 3.0    0.869920
# 1.0    0.080858
# 2.0    0.041426
# 7.0    0.005439
# 9.0    0.002357
# Name: smoking, dtype: float64

# %%
# code to graph those proportion of different smoking groups using matplotlib
fig, ax= plt.subplots()
ax.bar(['Non-Smoker', 'Everyday', 'Some Days', 'Dont Know', 'Refused'], smoking_avg)
ax.set_ylabel('Percent of survey')
ax.set_title("Smoking Status");

# %%
zero_dict = {3:'non', 
            2: 'some',
            1: 'every',
            7: 'unknown',
            9: 'unknown'}

df['smoking_cat'] = df['smoking'].replace(zero_dict)

# %%
state_smoking_cat = df.groupby(['_STATE', 'smoking_cat']).agg({'smoking_cat': 'count'})
#Change: groupby state_office and divide by sum
state_pcts_cat = state_smoking_cat.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))
state_pcts_cat.index.set_levels(['Conn', 'NJ', 'NY'], level=0, inplace=True)
state_pcts_cat
# Out:
#                     smoking_cat
# _STATE smoking_cat
# Conn   every           7.010127
#        non            88.565529
#        some            3.450988
#        unknown         0.973356
# NJ     every           8.200637
#        non            86.686129
#        some            4.281670
#        unknown         0.831564
# NY     every           8.915663
#        non            85.912220
#        some            4.612737
#        unknown         0.559380

# %%
state_pcts_cat.unstack()
# Out:
#             smoking_cat
# smoking_cat       every        non      some   unknown
# _STATE
# Conn           7.010127  88.565529  3.450988  0.973356
# NJ             8.200637  86.686129  4.281670  0.831564
# NY             8.915663  85.912220  4.612737  0.559380

# %%
ax= state_pcts_cat.unstack().plot(kind= 'bar', stacked= True);
ax.legend(bbox_to_anchor=(1,1));

# %%
cat_avg = df.groupby('smoking_cat')['PHYSHLTH'].mean()
cat_avg
# Out:
# smoking_cat
# every      6.491405
# non        3.684543
# some       6.134938
# unknown    3.686047
# Name: PHYSHLTH, dtype: float64

# %%
# code to graph these averages sick days for each category of smoking status
cat_avg.plot(kind= 'bar');

# %% [markdown]
# ## 7. Independent Variables (continuous):
#
# Does the amount of days a person drinks affect the number of days they feel physically ill?
# To investigate this, let's look at a continuous variable (ALCDAY5) and see how that might impact a person's health.
#
# 1. Clean up the values.
# 2. Calculate the descriptive statistics of the variable.
# 3. Generate a histogram for the variable.
# 4. Generate graphics that show how the responses to this variable might differ by state.
# 5. Calculate the correlation coefficient between `PHYSHLTH` and `ALCDAY5`.
# 5. Generate a graphic that shows the possible relationship between `PHYSHLTH` and `ALCDAY5`.

# %%
# code here to clean up the ALCDAY5 responses
alc_dict = {888:0, 
            777: np.nan,
            999: np.nan
            }

df['alcohol'] = df['ALCDAY5'].replace(alc_dict)
df['alcohol']
# Out:
# 49938     101.0
# 49939     230.0
# 49940       0.0
# 49941     103.0
# 49942     101.0
#           ...
# 303774    203.0
# 303775      0.0
# 303776    204.0
# 303777      NaN
# 303778    230.0
# Name: alcohol, Length: 34545, dtype: float64

# %%
def thirtydays(x):
    if x>200:
        return x-200
    elif x>100:
        return (x-100)*(30/7)
    else:
        return x

# %%
df['alcohol']= df['alcohol'].apply(thirtydays)
df['alcohol']
# Out:
# 49938      4.285714
# 49939     30.000000
# 49940      0.000000
# 49941     12.857143
# 49942      4.285714
#             ...
# 303774     3.000000
# 303775     0.000000
# 303776     4.000000
# 303777          NaN
# 303778    30.000000
# Name: alcohol, Length: 34545, dtype: float64

# %%
#descriptive statistics of cleaned data
df['alcohol'].describe()
# Out:
# count    32212.000000
# mean         5.431707
# std          8.386242
# min          0.000000
# 25%          0.000000
# 50%          2.000000
# 75%          7.000000
# max         30.000000
# Name: alcohol, dtype: float64

# %%
# graphic showing the histogram of data
alchist= df.alcohol.hist(bins= 20)
alchist.set_ylabel('Number of Observations')
alchist.set_xlabel('Days Drinking');

# %%
# code to calculate averages per state
alcohol_state = df.groupby('_STATE')['alcohol'].mean()
alcohol_state
# Out:
# _STATE
# 9.0     6.146279
# 34.0    5.014878
# 36.0    5.213151
# Name: alcohol, dtype: float64

# %%
# Code to calculate correlation of between number of drinks of number of days physically ill
df[['PHYSHLTH', 'alcohol']].corr()
# Out:
#           PHYSHLTH   alcohol
# PHYSHLTH  1.000000 -0.087438
# alcohol  -0.087438  1.000000

# %% [markdown]
# ## 8. Statistical Inference

# %% [markdown]
# - Create a 95% confidence interval for the population mean of physically ill days.

# %%
from statistics import stdev
df['PHYSHLTH'].mean() + or - (1.96)(stdev(df['PHYSHLTH'])/(len(df['PHYSHLTH']))
# Out:
#   File "<ipython-input-42-a67d4395c099>", line 2
#     df['PHYSHLTH'].mean() + or - (1.96)(stdev(df['PHYSHLTH'])/(len(df['PHYSHLTH']))
#                              ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import scipy.stats


def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

mean_confidence_interval(df['PHYSHLTH'])
# Out:
# (3.990968302214503, 3.9019979682611954, 4.07993863616781)

# %% [markdown]
# -  Create a 95% confidence interval for the true proportion of chronically sick people.

# %%
mean_confidence_interval(df['chronic'])
# Out:
# (0.12522796352583587, 0.12173756432445035, 0.1287183627272214)

# %% [markdown]
# ## 9. Hypothesis Tests

# %% [markdown]
# **For the follwing questions that require hypothesis tests, you must complete the following:**
#
# *1. Write down the null and alternative hypothesis you are testing.*
#
# *2. Select the appropriate test and calculate the test statistic and P-values.*
#
# *3. Determine the critical value for the 95% confidence interval.*
#
# *4. Evaluate the test statistic against the critical value.*
#
# *5. Determine if you reject or fail to reject the null hypothesis and write a sentence explaining the results of your hypothesis test.*

# %% [markdown]
# Answers
# 1)
# 2)
# 3) critical value: 1.96
# 4)
# 5)

# %% [markdown]
# ### The following questions are regarding the `PHYSHLTH` variable.
# - What is the probability of getting this sample mean for days physically ill, if the population mean is 4?
# - Is there a statistically significant difference between men and women in the number of days a person feels phsyically ill?
# - Perform a statistical test to determine if there statistically significant difference is physical health of people from the three states.

# %%
#H0) pop_mean = sample_mean 
#H1) pop_mean != sample_mean
#One sample T-test

# %%
mean_phys= df['PHYSHLTH'].mean()
length_pys= len(df['PHYSHLTH'])
phys_std= df['PHYSHLTH'].std()
dof= length_pys-1
dof
#alpha= 1-confidence interval
# Out:
# 34544

# %%
t_score= abs((mean_phys - 4)/(phys_std/length_pys**.5))
t_score
#probability= 0.5789
# Out:
# 0.19896994712190935

# %%
#The probability is greater than the alpha, we cant reject the null hypothesis

# %% [markdown]
# - Part 2 of Question 1

# %%
#H0) men_mean = women_mean H1) men_mean != women_mean

# %%
print(len(df.SEX))
len(df.PHYSHLTH)
# Out:
# 34545
# 34545

# %%
df.groupby('SEX').PHYSHLTH.mean()
# Out:
# SEX
# 1.0    3.617958
# 2.0    4.282247
# 9.0    4.619048
# Name: PHYSHLTH, dtype: float64

# %%
group1= df.groupby('SEX').PHYSHLTH.get_group(1)
group2= df.groupby('SEX').PHYSHLTH.get_group(2)

# %%
x =len(group1)+len(group2)

# %%
#z-test
import math
(group1.mean()-group2.mean())/math.sqrt(((group1.std())**2)/x + (((group2.std())**2)/x))
# Out:
# -10.389955868102309

# %%
from scipy import stats
stats.ttest_ind(group1,group2)
# Out:
# Ttest_indResult(statistic=-7.266686127789874, pvalue=3.7620556755911153e-13)

# %% [markdown]
# The P-Value is < .00001.
# The result is significant at p < .05
# Reject Null Hypothesis

# %% [markdown]
# 3

# %% [markdown]
# One way anova test

# %%
stats.f_oneway(df['PHYSHLTH'][df['_STATE'] == 9],
               df['PHYSHLTH'][df['_STATE'] == 34],
               df['PHYSHLTH'][df['_STATE'] == 36])
# Out:
# F_onewayResult(statistic=17.145321752116985, pvalue=3.610562736341162e-08)

# %% [markdown]
# At least one state is different in terms of their means. So the samples are from different populations.

# %% [markdown]
# 3.610562736341162e-08 < .05

# %% [markdown]
# ### The following questions are regarding the  `CHRONIC` variable.
# - What is the probability of drawing this sample proportion if chronically true population proportion is 0.10?
# - Is there a statistically significant difference in the percentage of men and women who are chronically sick?
# - Perform a statistical test to determine if there statistically significant difference is physical health of people from the three states.

# %% [markdown]
# # 10. Independent Investigation
#
# Now that you have invesitgated physical health and chronic sickness and their relationships with states and gender, you will conduct a similar investigation with variables of your choosing.
#
# Select a continuous dependent varaible and a binary dependent variable that you would like to investigate. Then select a categorical independent variable with at least 3 groups and for which you will test to see if the response to the independent variable affects outcomes of the dependent variable.

# %% [markdown]
# For your continuous dependent variable perform the following:
#   - Determine the sample mean and sample standard deviation
#   - Create a confidence interval for a population mean.
#   - Perform a two-sample test of means for gender.
#   - Perform a one-way ANOVA using your categorical independent variable.

# %% [markdown]
# Select/create a binary variable from the survey questions as you dependent variable and perform the following:
#   - Create a confidence interval for a population proportion.
#   - Perform a two proportions z-test using gender.
#   - Perform a Chi-Square test using your categorical independent variable.
